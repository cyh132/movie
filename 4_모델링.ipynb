# %% [markdown]
# ## import package

# %%
import pandas as pd
import numpy as np
import statsmodels.api as sm
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LinearRegression
from sklearn.cross_validation import cross_val_score

# %%
data_set = pd.read_csv("data_set.csv", index_col=0)
value_data_set = pd.read_csv("value_data_set.csv", index_col=0)
nation_df = pd.read_csv("nation.csv", index_col=0)
openDt_df = pd.read_csv("openDt.csv", index_col=0)
genre_df = pd.read_csv("genre.csv", index_col=0)
showTm_df = pd.read_csv("showTm.csv", index_col=0)
grade_df = pd.read_csv("grade.csv", index_col=0)
company_df = pd.read_csv("company.csv", index_col=0)

# %% [markdown]
# ## 모델링

# %%
modeling_data = pd.concat([value_data_set,data_set["audience"]],axis=1)

# %% [markdown]
# ### scaling

# %%
X = modeling_data.ix[:,:-1]
scaler = StandardScaler(with_mean=False)
X_scaled = scaler.fit_transform(X)

dfX0 = pd.DataFrame(X_scaled, columns=X.columns)
dfX = sm.add_constant(dfX0)
dfy = pd.DataFrame(modeling_data.ix[:,-1], columns=["audience"])
d_df = pd.concat([dfX, dfy], axis=1)
d_df.head()
# Out:
#    const  star_score  star_user_count  preview_audience  d1_audience  \
# 0      1    6.047889         0.090362          1.707643     0.951633
# 1      1    5.777558         0.024644          2.301215     1.180200
# 2      1    5.029430         0.042247          0.001781     1.669602
# 3      1    5.532373         0.011735          2.233447     1.171644
# 4      1    5.645535         0.159600          0.023506     0.343580
#
#    d2_audience  d3_audience  d4_audience  d5_audience  d6_audience    ...     \
# 0     1.125473     1.055735     0.905093     0.759425     1.226691    ...
# 1     1.674585     1.068647     0.393388     0.690482     2.151851    ...
# 2     2.547452     1.622128     0.545467     0.715350     1.054072    ...
# 3     2.128858     1.395356     0.377731     0.475672     0.738537    ...
# 4     0.309039     0.286235     0.614342     0.688012     0.252167    ...
#
#     d6_show   d7_show   d1_seat   d2_seat   d3_seat   d4_seat   d5_seat  \
# ...

# %% [markdown]
# ### Summary OLS

# %%
model = sm.OLS(d_df.ix[:, -1], d_df.ix[:, :-1])
result = model.fit()
print(result.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:               audience   R-squared:                       0.842
# Model:                            OLS   Adj. R-squared:                  0.841
# Method:                 Least Squares   F-statistic:                     442.9
# Date:                Sat, 23 Jul 2016   Prob (F-statistic):               0.00
# Time:                        15:16:33   Log-Likelihood:                -38151.
# No. Observations:                2600   AIC:                         7.637e+04
# Df Residuals:                    2568   BIC:                         7.655e+04
# Df Model:                          31
# Covariance Type:            nonrobust
# ...
#                        coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ------------------------------------------------------------------------------------
# const            -9.671e+04   7.06e+04     -1.369      0.171     -2.35e+05  4.18e+04
# ...

# %%
X = modeling_data.ix[:,:-1]
scaler = StandardScaler(with_mean=False)
X_scaled = scaler.fit_transform(X)

dfX0 = pd.DataFrame(X_scaled, columns=X.columns)
dfX = sm.add_constant(dfX0)
d_df = dfX
d_df.head()
# Out:
#    const  star_score  star_user_count  preview_audience  d1_audience  \
# 0      1    6.047889         0.090362          1.707643     0.951633
# 1      1    5.777558         0.024644          2.301215     1.180200
# 2      1    5.029430         0.042247          0.001781     1.669602
# 3      1    5.532373         0.011735          2.233447     1.171644
# 4      1    5.645535         0.159600          0.023506     0.343580
#
#    d2_audience  d3_audience  d4_audience  d5_audience  d6_audience    ...     \
# 0     1.125473     1.055735     0.905093     0.759425     1.226691    ...
# 1     1.674585     1.068647     0.393388     0.690482     2.151851    ...
# 2     2.547452     1.622128     0.545467     0.715350     1.054072    ...
# 3     2.128858     1.395356     0.377731     0.475672     0.738537    ...
# 4     0.309039     0.286235     0.614342     0.688012     0.252167    ...
#
#     d5_show   d6_show   d7_show   d1_seat   d2_seat   d3_seat   d4_seat  \
# ...

# %%
model = sm.OLS(dd_df.ix[:, -1], dd_df.ix[:, :-1])
result = model.fit()
print(result.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:               audience   R-squared:                       0.847
# Model:                            OLS   Adj. R-squared:                  0.843
# Method:                 Least Squares   F-statistic:                     194.5
# Date:                Sat, 23 Jul 2016   Prob (F-statistic):               0.00
# Time:                        15:15:09   Log-Likelihood:                -38112.
# No. Observations:                2600   AIC:                         7.637e+04
# Df Residuals:                    2527   BIC:                         7.680e+04
# Df Model:                          72
# Covariance Type:            nonrobust
# ...
#                            coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ----------------------------------------------------------------------------------------
# const                -8.639e+04   4.55e+04     -1.897      0.058     -1.76e+05  2928.077
# ...

# %%
model = LinearRegression()
model.fit(d_df.ix[:, :-1], d_df.ix[:, -1])
# Out:
# /Users/Cho/.pyenv/versions/3.5.1/envs/dss/lib/python3.5/site-packages/scipy/linalg/basic.py:884: RuntimeWarning: internal gelsd driver lwork query error, required iwork dimension not returned. This is likely the result of LAPACK bug 0038, fixed in LAPACK 3.2.2 (released July 21, 2010). Falling back to 'gelss' driver.
#   warnings.warn(mesg, RuntimeWarning)
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False)

# %%
w = model.coef_[1:]

# %%
N = 5
print(d_df.loc[N])
v = np.array(d_df.loc[N][1:-1])

print(w)
print(v)

# predict
print( (w*v).sum() )
# Out:
# const               1.000000e+00
# star_score          5.796418e+00
# star_user_count     4.295119e-01
# preview_audience    3.124309e+00
# d1_audience         5.671095e+00
# d2_audience         3.431559e+00
# d3_audience         4.507592e+00
# d4_audience         3.574407e+00
# d5_audience         3.909048e+00
# d6_audience         1.882611e+00
# d7_audience         1.619024e+00
# d1_screen           2.768075e+00
# d2_screen           2.820256e+00
# d3_screen           2.896880e+00
# d4_screen           2.816354e+00
# d5_screen           2.870696e+00
# d6_screen           3.043378e+00
# d7_screen           3.092250e+00
# d1_show             2.905769e+00
# d2_show             2.941088e+00
# d3_show             3.055087e+00
# d4_show             3.062492e+00
# d5_show             3.067591e+00
# d6_show             3.055541e+00
# d7_show             3.086763e+00
# d1_seat             4.018938e+00
# d2_seat             2.230424e+00
# d3_seat             3.523529e+00
# ...

# %%
data_set
# Out:
#        movieCd                movieNm  star_score  star_user_count  \
# 0     20030371               태극기 휘날리며        9.62               77
# 1     20040555                    트로이        9.19               21
# 2     20040673            내 머리 속의 지우개        8.00               36
# 3     20040649                 귀신이 산다        8.80               10
# 4     20159748                 투모로우랜드        8.98              136
# 5     20148807             엣지 오브 투모로우        9.22              366
# 6     20040628                   우리 형        8.31               14
# 7     20040598         해리포터와 아즈카반의 죄수        8.83               48
# 8     20040566                    슈렉2        7.35               17
# 9     20030410                    실미도        7.68               29
# 10    20135661           어메이징 스파이더맨 2        9.03              697
# 11    20040491                스파이더맨 2       10.00                6
# 12    20040596                바람의 파이터        9.00               11
# ...
